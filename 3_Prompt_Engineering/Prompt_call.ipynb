# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()

llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

# %% [markdown]
# 1. Zero-Shot Prompting

# %%
llm.invoke("Translate the following English sentence to French: 'How are you?'")
# Out:
# AIMessage(content='Comment vas-tu ?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 20, 'total_tokens': 25, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EP53E92B8GgRdiSmCDSFRrlNEyxtd', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0af3b-c2ea-72a0-a91d-b6421b7cdf6c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 5, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# 2. One-Shot Prompting

# %%
one_shot_prompt = (
    "Translate the following English sentence to French.\n"
    "Example: 'Good morning' -> 'Bonjour'\n"
    "Now, translate: 'How are you?'"
)
llm.invoke(one_shot_prompt)
# Out:
# AIMessage(content='Comment vas-tu ?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 34, 'total_tokens': 39, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EP53aZ9cCWSauWxJDMM96wsym0iof', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0af3c-1a64-7522-80af-e661b07b60aa-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 34, 'output_tokens': 5, 'total_tokens': 39, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# 3. Few-Shot Prompting

# %%
few_shot_prompt = (
    "Translate the following English sentences to French.\n"
    "Example 1: 'Good morning' -> 'Bonjour'\n"
    "Example 2: 'Thank you' -> 'Merci'\n"
    "Now, translate: 'How are you?'"
)
llm.invoke(few_shot_prompt)
# Out:
# AIMessage(content='Comment ça va ?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 4, 'prompt_tokens': 49, 'total_tokens': 53, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EP53vmhqgc2BxNH4y6cXcB4IQcted', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0af3c-6d10-78d2-9373-ff3c98c53a82-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 4, 'total_tokens': 53, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# 4. Chain-of-Thought Prompting

# %%
cot_prompt = (
    "Solve the following math problem step by step.\n"
    "Question: If you have 10 apples and get 20 more, how many apples do you have?\n"
    "Example:\n"
    "Question: If you have 3 apples and get 2 more, how many apples do you have?\n"
    "Let's think step by step.\n"
    "Step 1: Start with 3 apples.\n"
    "Step 2: Get 2 more apples.\n"
    "Step 3: 3 + 2 = 5.\n"
    "Answer: 5 apples."
)
llm.invoke(cot_prompt)
# Out:
# AIMessage(content="Let's solve the given problem step by step.\nStep 1: Start with 10 apples.\nStep 2: Get 20 more apples.\nStep 3: 10 + 20 = 30.\nAnswer: You have 30 apples.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 51, 'prompt_tokens': 107, 'total_tokens': 158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EP54Ljz3lPc4ETODke9RR4WVXN1Bc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0af3c-d077-7721-b24a-ac4fea1cfb55-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 51, 'total_tokens': 158, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
